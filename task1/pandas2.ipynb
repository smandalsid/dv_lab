# %%
import pandas as pd
df=pd.read_csv('/home/siddharth/Documents/ubuntu_python_work/pandas/olympic_medals.csv')

# %%
print(df[['discipline_title', 'slug_game']])
# Out:
#       discipline_title    slug_game
# 0             Shooting   tokyo-2020
# 1             Shooting   tokyo-2020
# 2             Shooting   tokyo-2020
# 3             Shooting   tokyo-2020
# 4             Shooting   tokyo-2020
# ...                ...          ...
# 21305    Weightlifting  athens-1896
# 21306    Weightlifting  athens-1896
# 21307    Weightlifting  athens-1896
# 21308    Weightlifting  athens-1896
# 21309    Weightlifting  athens-1896
#
# [21310 rows x 2 columns]

# %%
for i in range(len(df['discipline_title'])):
    if df['discipline_title'][i]=='Shooting':
        print(df['discipline_title'][i], end="\t")
        print(df['slug_game'][i])
# Out:
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# Shooting	tokyo-2020
# ...
